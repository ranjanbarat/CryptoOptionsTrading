# %%
import httpx
import pandas as pd
import numpy as np
import datetime
from datetime import datetime
import time

# %%
api_url = "https://api-demo.bybit.com"
api_endpoint = "/v5/market/tickers"

api_parameters = {'category': "option",
                  'baseCoin': "BTC"}

# %%
start = time.perf_counter()

# Make an Async API Call to fetch the Full Option Table
async with httpx.AsyncClient() as client:
    # Await Data from the GET Request
    r = await client.get(url=f"{api_url}" + f"{api_endpoint}", params=api_parameters)
    # Check if We have Received the Data or its Data Error
    if r.status_code == 200:
        # Print the Length of the Option Chain that we have Received from the API Call
        print(f"Tickers Data Retrieval Success : Data Count : {len(r.json()['result']['list'])}")
        # Convert the JSON Data into Pandas DataFrame for Further Processing
        dataframe = pd.json_normalize(data=r.json()['result']['list'])
    else:
        # Print the Error Message if No Data is Received
        print(f"Error in Retrieving the Tickers Data : Error Code : {r.status_code}")

end = time.perf_counter()
print(f"Data Fetching from ByBit API is Completed in : {(end - start) * 10 ** 3} ms \n")
# Out:
# Tickers Data Retrieval Success : Data Count : 520
# Data Fetching from ByBit API is Completed in : 927.9513329965994 ms

# %%
start = time.perf_counter()

# Convert the "DataFrame" dtype: "Object" into their Correct dtypes
try :
    dataframe['symbol'] = dataframe['symbol'].astype(dtype="string")
except Exception as e:
    print(f"Error in formatting 'symbol', Error Code : {e}")

try :
    dataframe['bid1Price'] = dataframe['bid1Price'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'bid1Price', Error Code : {e}")

try :
    dataframe['bid1Size'] = dataframe['bid1Size'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'bid1Size', Error Code : {e}")

try :
    dataframe['bid1Iv'] = dataframe['bid1Iv'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'bid1Iv', Error Code : {e}")

try :
    dataframe['ask1Price'] = dataframe['ask1Price'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'ask1Price', Error Code : {e}")

try :
    dataframe['ask1Size'] = dataframe['ask1Size'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'ask1Size', Error Code : {e}")

try :
    dataframe['ask1Iv'] = dataframe['ask1Iv'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'ask1Iv', Error Code : {e}")

try :
    dataframe['lastPrice'] = dataframe['lastPrice'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'lastPrice', Error Code : {e}")

try :
    dataframe['highPrice24h'] = dataframe['highPrice24h'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'highPrice24h', Error Code : {e}")

try :
    dataframe['lowPrice24h'] = dataframe['lowPrice24h'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'lowPrice24h', Error Code : {e}")

try :
    dataframe['markPrice'] = dataframe['markPrice'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'markPrice', Error Code : {e}")

try :
    dataframe['underlyingPrice'] = dataframe['underlyingPrice'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'underlyingPrice', Error Code : {e}")

try :
    dataframe['indexPrice'] = dataframe['indexPrice'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'indexPrice', Error Code : {e}")

try :
    dataframe['markIv'] = dataframe['markIv'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'markIv', Error Code : {e}")

try :
    dataframe['underlyingPrice'] = dataframe['underlyingPrice'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'underlyingPrice', Error Code : {e}")

try :
    dataframe['openInterest'] = dataframe['openInterest'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'openInterest', Error Code : {e}")

try :
    dataframe['turnover24h'] = dataframe['turnover24h'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'turnover24h', Error Code : {e}")

try :
    dataframe['volume24h'] = dataframe['volume24h'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'volume24h', Error Code : {e}")

try :
    dataframe['totalVolume'] = dataframe['totalVolume'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'totalVolume', Error Code : {e}")

try :
    dataframe['totalTurnover'] = dataframe['totalTurnover'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'totalTurnover', Error Code : {e}")

try :
    dataframe['delta'] = dataframe['delta'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'delta', Error Code : {e}")

try :
    dataframe['gamma'] = dataframe['gamma'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'gamma', Error Code : {e}")

try :
    dataframe['vega'] = dataframe['vega'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'vega', Error Code : {e}")

try :
    dataframe['theta'] = dataframe['theta'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'theta', Error Code : {e}")

try :
    dataframe['predictedDeliveryPrice'] = dataframe['predictedDeliveryPrice'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'predictedDeliveryPrice', Error Code : {e}")

try :
    dataframe['change24h'] = dataframe['change24h'].astype(dtype="float64")
except Exception as e:
    print(f"Error in formatting 'change24h', Error Code : {e}")

# %%
# Initialize Options_Type Numpy Array, we need to fill it with actual Values after Splitting the Symbol String
# We are Initialing Filling "UNKNOWN" as String Value, Later it will be replaced by "CALL" or "PUT"
option_type = np.array(["UNKNOWN" for _ in range(len(dataframe))])

# Initialize Strike_Price Numpy Array, we need to fill it with actual Values after Splitting the Symbol String
# We are Initialing Filling "-5000" as Float64 Value, Later it will be replaced by Actual Strike Price
strike_price = np.array([-5000.00 for _ in range(len(dataframe))])

# Initialize Expiry_Date Numpy Array; we need to fill it with actual Values after Splitting the Symbol String
# We are Initialing Filling "1-1-2000" as datetime Value, Later it will be replaced by Actual Expiry Dates
expiry = np.array([datetime(year=2000, month=1, day=1).date() for _ in range(len(dataframe))])

# %%
# ByBit Date Format to Extract the Date from Splitting the Symbol Value
ByBit_date_format = "%d%b%y"  # Date Format as (DD)(MMM)(YY)

for i in range((len(dataframe))):
    # Try to Split the String using "-" as the Spliter
    try:
        split_symbol = dataframe.symbol[i].split("-")
        # Confirm the Data by Printing the Outcome as Logs
        print(f"Symbol Data {i} was Split Correctly : {split_symbol}")
    # Catch the arising Exception if any, then Print it as Log
    except Exception as e:
        print(f"Error Occurred while splitting the Symbol Value : {dataframe.symbol[i]} ")
        print(f"Error Details : {e}")

    # Convert the Split String Value into Expiry Date in ByBit Specific Date Format
    # It will remain "1-1-2000" for error Cases
    try:
        expiry[i] = datetime.strptime(str(split_symbol[1]), ByBit_date_format).date()
        print(f"Successfully Updated the {i} Expiry Date  Type as : {expiry[i]}")
    # Catch the arising Exception if any, then Print it as Log
    except Exception as e:
        print(f"Error Details : {e}")
        print(f"Error Occurred while Updating the Options Expiry Date : {split_symbol[1]} ")
        print(f"Finally processing Expiry Date as : {expiry[i]}")

    # Convert the Split String Value into Option Strike Price in Float64 dtype
    # It will remain "-5000.00" for error Cases
    try:
        strike_price[i] = float(split_symbol[2])
        print(f"Successfully Updated the {i} Strike Price as : {strike_price[i]}")
    # Catch the arising Exception if any, then Print it as Log
    except Exception as e:
        print(f"Error Details : {e}")
        print(f"Error Occurred while Updating the Options Strike Price : {split_symbol[2]} ")
        print(f"Finally processing Strike_Price as : {strike_price[i]}")

    # Convert the Split String Value into Option Type: Either "PUT" or "CALL"
    # It will remain "UNKNOWN" for error Cases
    try:
        if split_symbol[3] == "P":
            option_type[i] = "PUT"
        elif split_symbol[3] == "C":
            option_type[i] = "CALL"

        print(f"Successfully Updated the {i} Option Type as : {option_type[i]}")
    # Catch the arising Exception if any, then Print it as Log
    except Exception as e:
        print(f"Error Details : {e}")
        print(f"Error Occurred while Updating the Options Type : {split_symbol[3]} ")
        print(f"Finally processing Options Type as : {option_type[i]}")
# Out:
# Symbol Data 0 was Split Correctly : ['BTC', '27DEC24', '85000', 'C']
# Successfully Updated the 0 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 0 Strike Price as : 85000.0
# Successfully Updated the 0 Option Type as : CALL
# Symbol Data 1 was Split Correctly : ['BTC', '27DEC24', '95000', 'P']
# Successfully Updated the 1 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 1 Strike Price as : 95000.0
# Successfully Updated the 1 Option Type as : PUT
# Symbol Data 2 was Split Correctly : ['BTC', '27DEC24', '75000', 'C']
# Successfully Updated the 2 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 2 Strike Price as : 75000.0
# Successfully Updated the 2 Option Type as : CALL
# Symbol Data 3 was Split Correctly : ['BTC', '27DEC24', '44000', 'P']
# Successfully Updated the 3 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 3 Strike Price as : 44000.0
# Successfully Updated the 3 Option Type as : PUT
# Symbol Data 4 was Split Correctly : ['BTC', '27DEC24', '32000', 'P']
# Successfully Updated the 4 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 4 Strike Price as : 32000.0
# Successfully Updated the 4 Option Type as : PUT
# Symbol Data 5 was Split Correctly : ['BTC', '27DEC24', '180000', 'C']
# Successfully Updated the 5 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 5 Strike Price as : 180000.0
# Successfully Updated the 5 Option Type as : CALL
# Symbol Data 6 was Split Correctly : ['BTC', '27DEC24', '120000', 'C']
# Successfully Updated the 6 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 6 Strike Price as : 120000.0
# Successfully Updated the 6 Option Type as : CALL
# Symbol Data 7 was Split Correctly : ['BTC', '27DEC24', '78000', 'P']
# Successfully Updated the 7 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 7 Strike Price as : 78000.0
# Successfully Updated the 7 Option Type as : PUT
# Symbol Data 8 was Split Correctly : ['BTC', '27DEC24', '64000', 'P']
# Successfully Updated the 8 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 8 Strike Price as : 64000.0
# Successfully Updated the 8 Option Type as : PUT
# Symbol Data 9 was Split Correctly : ['BTC', '27DEC24', '220000', 'C']
# Successfully Updated the 9 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 9 Strike Price as : 220000.0
# Successfully Updated the 9 Option Type as : CALL
# Symbol Data 10 was Split Correctly : ['BTC', '27DEC24', '70000', 'P']
# Successfully Updated the 10 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 10 Strike Price as : 70000.0
# Successfully Updated the 10 Option Type as : PUT
# Symbol Data 11 was Split Correctly : ['BTC', '27DEC24', '52000', 'C']
# Successfully Updated the 11 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 11 Strike Price as : 52000.0
# Successfully Updated the 11 Option Type as : CALL
# Symbol Data 12 was Split Correctly : ['BTC', '27DEC24', '38000', 'C']
# Successfully Updated the 12 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 12 Strike Price as : 38000.0
# Successfully Updated the 12 Option Type as : CALL
# Symbol Data 13 was Split Correctly : ['BTC', '27DEC24', '65000', 'P']
# Successfully Updated the 13 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 13 Strike Price as : 65000.0
# Successfully Updated the 13 Option Type as : PUT
# Symbol Data 14 was Split Correctly : ['BTC', '27DEC24', '69000', 'P']
# Successfully Updated the 14 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 14 Strike Price as : 69000.0
# Successfully Updated the 14 Option Type as : PUT
# Symbol Data 15 was Split Correctly : ['BTC', '27DEC24', '55000', 'C']
# Successfully Updated the 15 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 15 Strike Price as : 55000.0
# Successfully Updated the 15 Option Type as : CALL
# Symbol Data 16 was Split Correctly : ['BTC', '27DEC24', '50000', 'C']
# Successfully Updated the 16 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 16 Strike Price as : 50000.0
# Successfully Updated the 16 Option Type as : CALL
# Symbol Data 17 was Split Correctly : ['BTC', '27DEC24', '200000', 'C']
# Successfully Updated the 17 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 17 Strike Price as : 200000.0
# Successfully Updated the 17 Option Type as : CALL
# Symbol Data 18 was Split Correctly : ['BTC', '27DEC24', '63000', 'C']
# Successfully Updated the 18 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 18 Strike Price as : 63000.0
# Successfully Updated the 18 Option Type as : CALL
# Symbol Data 19 was Split Correctly : ['BTC', '27DEC24', '110000', 'P']
# Successfully Updated the 19 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 19 Strike Price as : 110000.0
# Successfully Updated the 19 Option Type as : PUT
# Symbol Data 20 was Split Correctly : ['BTC', '27DEC24', '65000', 'C']
# Successfully Updated the 20 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 20 Strike Price as : 65000.0
# Successfully Updated the 20 Option Type as : CALL
# Symbol Data 21 was Split Correctly : ['BTC', '27DEC24', '70000', 'C']
# Successfully Updated the 21 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 21 Strike Price as : 70000.0
# Successfully Updated the 21 Option Type as : CALL
# Symbol Data 22 was Split Correctly : ['BTC', '27DEC24', '46000', 'P']
# Successfully Updated the 22 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 22 Strike Price as : 46000.0
# Successfully Updated the 22 Option Type as : PUT
# Symbol Data 23 was Split Correctly : ['BTC', '27DEC24', '60000', 'P']
# Successfully Updated the 23 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 23 Strike Price as : 60000.0
# Successfully Updated the 23 Option Type as : PUT
# Symbol Data 24 was Split Correctly : ['BTC', '27DEC24', '36000', 'P']
# Successfully Updated the 24 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 24 Strike Price as : 36000.0
# Successfully Updated the 24 Option Type as : PUT
# Symbol Data 25 was Split Correctly : ['BTC', '27DEC24', '25000', 'C']
# Successfully Updated the 25 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 25 Strike Price as : 25000.0
# Successfully Updated the 25 Option Type as : CALL
# Symbol Data 26 was Split Correctly : ['BTC', '27DEC24', '80000', 'P']
# Successfully Updated the 26 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 26 Strike Price as : 80000.0
# Successfully Updated the 26 Option Type as : PUT
# Symbol Data 27 was Split Correctly : ['BTC', '27DEC24', '28000', 'C']
# Successfully Updated the 27 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 27 Strike Price as : 28000.0
# Successfully Updated the 27 Option Type as : CALL
# Symbol Data 28 was Split Correctly : ['BTC', '27DEC24', '52000', 'P']
# Successfully Updated the 28 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 28 Strike Price as : 52000.0
# Successfully Updated the 28 Option Type as : PUT
# Symbol Data 29 was Split Correctly : ['BTC', '27DEC24', '95000', 'C']
# Successfully Updated the 29 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 29 Strike Price as : 95000.0
# Successfully Updated the 29 Option Type as : CALL
# Symbol Data 30 was Split Correctly : ['BTC', '27DEC24', '42000', 'P']
# Successfully Updated the 30 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 30 Strike Price as : 42000.0
# Successfully Updated the 30 Option Type as : PUT
# Symbol Data 31 was Split Correctly : ['BTC', '27DEC24', '48000', 'P']
# Successfully Updated the 31 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 31 Strike Price as : 48000.0
# Successfully Updated the 31 Option Type as : PUT
# Symbol Data 32 was Split Correctly : ['BTC', '27DEC24', '74000', 'C']
# Successfully Updated the 32 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 32 Strike Price as : 74000.0
# Successfully Updated the 32 Option Type as : CALL
# Symbol Data 33 was Split Correctly : ['BTC', '27DEC24', '20000', 'C']
# Successfully Updated the 33 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 33 Strike Price as : 20000.0
# Successfully Updated the 33 Option Type as : CALL
# Symbol Data 34 was Split Correctly : ['BTC', '27DEC24', '90000', 'P']
# Successfully Updated the 34 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 34 Strike Price as : 90000.0
# Successfully Updated the 34 Option Type as : PUT
# Symbol Data 35 was Split Correctly : ['BTC', '27DEC24', '80000', 'C']
# Successfully Updated the 35 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 35 Strike Price as : 80000.0
# Successfully Updated the 35 Option Type as : CALL
# Symbol Data 36 was Split Correctly : ['BTC', '27DEC24', '130000', 'P']
# Successfully Updated the 36 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 36 Strike Price as : 130000.0
# Successfully Updated the 36 Option Type as : PUT
# Symbol Data 37 was Split Correctly : ['BTC', '27DEC24', '38000', 'P']
# Successfully Updated the 37 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 37 Strike Price as : 38000.0
# Successfully Updated the 37 Option Type as : PUT
# Symbol Data 38 was Split Correctly : ['BTC', '27DEC24', '32000', 'C']
# Successfully Updated the 38 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 38 Strike Price as : 32000.0
# Successfully Updated the 38 Option Type as : CALL
# Symbol Data 39 was Split Correctly : ['BTC', '27DEC24', '58000', 'P']
# Successfully Updated the 39 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 39 Strike Price as : 58000.0
# Successfully Updated the 39 Option Type as : PUT
# Symbol Data 40 was Split Correctly : ['BTC', '27DEC24', '160000', 'C']
# Successfully Updated the 40 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 40 Strike Price as : 160000.0
# Successfully Updated the 40 Option Type as : CALL
# Symbol Data 41 was Split Correctly : ['BTC', '27DEC24', '60000', 'C']
# Successfully Updated the 41 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 41 Strike Price as : 60000.0
# Successfully Updated the 41 Option Type as : CALL
# Symbol Data 42 was Split Correctly : ['BTC', '27DEC24', '48000', 'C']
# Successfully Updated the 42 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 42 Strike Price as : 48000.0
# Successfully Updated the 42 Option Type as : CALL
# Symbol Data 43 was Split Correctly : ['BTC', '27DEC24', '160000', 'P']
# Successfully Updated the 43 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 43 Strike Price as : 160000.0
# Successfully Updated the 43 Option Type as : PUT
# Symbol Data 44 was Split Correctly : ['BTC', '27DEC24', '100000', 'C']
# Successfully Updated the 44 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 44 Strike Price as : 100000.0
# Successfully Updated the 44 Option Type as : CALL
# Symbol Data 45 was Split Correctly : ['BTC', '27DEC24', '220000', 'P']
# Successfully Updated the 45 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 45 Strike Price as : 220000.0
# Successfully Updated the 45 Option Type as : PUT
# Symbol Data 46 was Split Correctly : ['BTC', '27DEC24', '30000', 'P']
# Successfully Updated the 46 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 46 Strike Price as : 30000.0
# Successfully Updated the 46 Option Type as : PUT
# Symbol Data 47 was Split Correctly : ['BTC', '27DEC24', '180000', 'P']
# Successfully Updated the 47 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 47 Strike Price as : 180000.0
# Successfully Updated the 47 Option Type as : PUT
# Symbol Data 48 was Split Correctly : ['BTC', '27DEC24', '25000', 'P']
# Successfully Updated the 48 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 48 Strike Price as : 25000.0
# Successfully Updated the 48 Option Type as : PUT
# Symbol Data 49 was Split Correctly : ['BTC', '27DEC24', '36000', 'C']
# Successfully Updated the 49 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 49 Strike Price as : 36000.0
# Successfully Updated the 49 Option Type as : CALL
# Symbol Data 50 was Split Correctly : ['BTC', '27DEC24', '30000', 'C']
# Successfully Updated the 50 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 50 Strike Price as : 30000.0
# Successfully Updated the 50 Option Type as : CALL
# Symbol Data 51 was Split Correctly : ['BTC', '27DEC24', '34000', 'P']
# Successfully Updated the 51 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 51 Strike Price as : 34000.0
# Successfully Updated the 51 Option Type as : PUT
# Symbol Data 52 was Split Correctly : ['BTC', '27DEC24', '200000', 'P']
# Successfully Updated the 52 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 52 Strike Price as : 200000.0
# Successfully Updated the 52 Option Type as : PUT
# Symbol Data 53 was Split Correctly : ['BTC', '27DEC24', '40000', 'C']
# Successfully Updated the 53 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 53 Strike Price as : 40000.0
# Successfully Updated the 53 Option Type as : CALL
# Symbol Data 54 was Split Correctly : ['BTC', '27DEC24', '50000', 'P']
# Successfully Updated the 54 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 54 Strike Price as : 50000.0
# Successfully Updated the 54 Option Type as : PUT
# Symbol Data 55 was Split Correctly : ['BTC', '27DEC24', '64000', 'C']
# Successfully Updated the 55 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 55 Strike Price as : 64000.0
# Successfully Updated the 55 Option Type as : CALL
# Symbol Data 56 was Split Correctly : ['BTC', '27DEC24', '56000', 'P']
# Successfully Updated the 56 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 56 Strike Price as : 56000.0
# Successfully Updated the 56 Option Type as : PUT
# Symbol Data 57 was Split Correctly : ['BTC', '27DEC24', '66000', 'C']
# Successfully Updated the 57 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 57 Strike Price as : 66000.0
# Successfully Updated the 57 Option Type as : CALL
# Symbol Data 58 was Split Correctly : ['BTC', '27DEC24', '15000', 'P']
# Successfully Updated the 58 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 58 Strike Price as : 15000.0
# Successfully Updated the 58 Option Type as : PUT
# Symbol Data 59 was Split Correctly : ['BTC', '27DEC24', '34000', 'C']
# Successfully Updated the 59 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 59 Strike Price as : 34000.0
# Successfully Updated the 59 Option Type as : CALL
# Symbol Data 60 was Split Correctly : ['BTC', '27DEC24', '15000', 'C']
# Successfully Updated the 60 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 60 Strike Price as : 15000.0
# Successfully Updated the 60 Option Type as : CALL
# Symbol Data 61 was Split Correctly : ['BTC', '27DEC24', '28000', 'P']
# Successfully Updated the 61 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 61 Strike Price as : 28000.0
# Successfully Updated the 61 Option Type as : PUT
# Symbol Data 62 was Split Correctly : ['BTC', '27DEC24', '140000', 'P']
# Successfully Updated the 62 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 62 Strike Price as : 140000.0
# Successfully Updated the 62 Option Type as : PUT
# Symbol Data 63 was Split Correctly : ['BTC', '27DEC24', '55000', 'P']
# Successfully Updated the 63 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 63 Strike Price as : 55000.0
# Successfully Updated the 63 Option Type as : PUT
# Symbol Data 64 was Split Correctly : ['BTC', '27DEC24', '46000', 'C']
# Successfully Updated the 64 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 64 Strike Price as : 46000.0
# Successfully Updated the 64 Option Type as : CALL
# Symbol Data 65 was Split Correctly : ['BTC', '27DEC24', '100000', 'P']
# Successfully Updated the 65 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 65 Strike Price as : 100000.0
# Successfully Updated the 65 Option Type as : PUT
# Symbol Data 66 was Split Correctly : ['BTC', '27DEC24', '85000', 'P']
# Successfully Updated the 66 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 66 Strike Price as : 85000.0
# Successfully Updated the 66 Option Type as : PUT
# Symbol Data 67 was Split Correctly : ['BTC', '27DEC24', '40000', 'P']
# Successfully Updated the 67 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 67 Strike Price as : 40000.0
# Successfully Updated the 67 Option Type as : PUT
# Symbol Data 68 was Split Correctly : ['BTC', '27DEC24', '110000', 'C']
# Successfully Updated the 68 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 68 Strike Price as : 110000.0
# Successfully Updated the 68 Option Type as : CALL
# Symbol Data 69 was Split Correctly : ['BTC', '27DEC24', '120000', 'P']
# Successfully Updated the 69 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 69 Strike Price as : 120000.0
# Successfully Updated the 69 Option Type as : PUT
# Symbol Data 70 was Split Correctly : ['BTC', '27DEC24', '20000', 'P']
# Successfully Updated the 70 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 70 Strike Price as : 20000.0
# Successfully Updated the 70 Option Type as : PUT
# Symbol Data 71 was Split Correctly : ['BTC', '27DEC24', '130000', 'C']
# Successfully Updated the 71 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 71 Strike Price as : 130000.0
# Successfully Updated the 71 Option Type as : CALL
# Symbol Data 72 was Split Correctly : ['BTC', '27DEC24', '74000', 'P']
# Successfully Updated the 72 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 72 Strike Price as : 74000.0
# Successfully Updated the 72 Option Type as : PUT
# Symbol Data 73 was Split Correctly : ['BTC', '27DEC24', '44000', 'C']
# Successfully Updated the 73 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 73 Strike Price as : 44000.0
# Successfully Updated the 73 Option Type as : CALL
# Symbol Data 74 was Split Correctly : ['BTC', '27DEC24', '66000', 'P']
# Successfully Updated the 74 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 74 Strike Price as : 66000.0
# Successfully Updated the 74 Option Type as : PUT
# Symbol Data 75 was Split Correctly : ['BTC', '27DEC24', '58000', 'C']
# Successfully Updated the 75 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 75 Strike Price as : 58000.0
# Successfully Updated the 75 Option Type as : CALL
# Symbol Data 76 was Split Correctly : ['BTC', '27DEC24', '75000', 'P']
# Successfully Updated the 76 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 76 Strike Price as : 75000.0
# Successfully Updated the 76 Option Type as : PUT
# Symbol Data 77 was Split Correctly : ['BTC', '27DEC24', '90000', 'C']
# Successfully Updated the 77 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 77 Strike Price as : 90000.0
# Successfully Updated the 77 Option Type as : CALL
# Symbol Data 78 was Split Correctly : ['BTC', '27DEC24', '42000', 'C']
# Successfully Updated the 78 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 78 Strike Price as : 42000.0
# Successfully Updated the 78 Option Type as : CALL
# Symbol Data 79 was Split Correctly : ['BTC', '27DEC24', '78000', 'C']
# Successfully Updated the 79 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 79 Strike Price as : 78000.0
# Successfully Updated the 79 Option Type as : CALL
# Symbol Data 80 was Split Correctly : ['BTC', '27DEC24', '63000', 'P']
# Successfully Updated the 80 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 80 Strike Price as : 63000.0
# Successfully Updated the 80 Option Type as : PUT
# Symbol Data 81 was Split Correctly : ['BTC', '27DEC24', '69000', 'C']
# Successfully Updated the 81 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 81 Strike Price as : 69000.0
# Successfully Updated the 81 Option Type as : CALL
# Symbol Data 82 was Split Correctly : ['BTC', '27DEC24', '140000', 'C']
# Successfully Updated the 82 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 82 Strike Price as : 140000.0
# Successfully Updated the 82 Option Type as : CALL
# Symbol Data 83 was Split Correctly : ['BTC', '27DEC24', '56000', 'C']
# Successfully Updated the 83 Expiry Date  Type as : 2024-12-27
# Successfully Updated the 83 Strike Price as : 56000.0
# Successfully Updated the 83 Option Type as : CALL
# Symbol Data 84 was Split Correctly : ['BTC', '27OCT24', '70000', 'P']
# Successfully Updated the 84 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 84 Strike Price as : 70000.0
# Successfully Updated the 84 Option Type as : PUT
# Symbol Data 85 was Split Correctly : ['BTC', '27OCT24', '67000', 'C']
# Successfully Updated the 85 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 85 Strike Price as : 67000.0
# Successfully Updated the 85 Option Type as : CALL
# Symbol Data 86 was Split Correctly : ['BTC', '27OCT24', '67500', 'P']
# Successfully Updated the 86 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 86 Strike Price as : 67500.0
# Successfully Updated the 86 Option Type as : PUT
# Symbol Data 87 was Split Correctly : ['BTC', '27OCT24', '66500', 'C']
# Successfully Updated the 87 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 87 Strike Price as : 66500.0
# Successfully Updated the 87 Option Type as : CALL
# Symbol Data 88 was Split Correctly : ['BTC', '27OCT24', '63000', 'C']
# Successfully Updated the 88 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 88 Strike Price as : 63000.0
# Successfully Updated the 88 Option Type as : CALL
# Symbol Data 89 was Split Correctly : ['BTC', '27OCT24', '73000', 'P']
# Successfully Updated the 89 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 89 Strike Price as : 73000.0
# Successfully Updated the 89 Option Type as : PUT
# Symbol Data 90 was Split Correctly : ['BTC', '27OCT24', '66000', 'C']
# Successfully Updated the 90 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 90 Strike Price as : 66000.0
# Successfully Updated the 90 Option Type as : CALL
# Symbol Data 91 was Split Correctly : ['BTC', '27OCT24', '71000', 'C']
# Successfully Updated the 91 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 91 Strike Price as : 71000.0
# Successfully Updated the 91 Option Type as : CALL
# Symbol Data 92 was Split Correctly : ['BTC', '27OCT24', '63000', 'P']
# Successfully Updated the 92 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 92 Strike Price as : 63000.0
# Successfully Updated the 92 Option Type as : PUT
# Symbol Data 93 was Split Correctly : ['BTC', '27OCT24', '68000', 'P']
# Successfully Updated the 93 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 93 Strike Price as : 68000.0
# Successfully Updated the 93 Option Type as : PUT
# Symbol Data 94 was Split Correctly : ['BTC', '27OCT24', '65500', 'C']
# Successfully Updated the 94 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 94 Strike Price as : 65500.0
# Successfully Updated the 94 Option Type as : CALL
# Symbol Data 95 was Split Correctly : ['BTC', '27OCT24', '67000', 'P']
# Successfully Updated the 95 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 95 Strike Price as : 67000.0
# Successfully Updated the 95 Option Type as : PUT
# Symbol Data 96 was Split Correctly : ['BTC', '27OCT24', '67500', 'C']
# Successfully Updated the 96 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 96 Strike Price as : 67500.0
# Successfully Updated the 96 Option Type as : CALL
# Symbol Data 97 was Split Correctly : ['BTC', '27OCT24', '62000', 'C']
# Successfully Updated the 97 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 97 Strike Price as : 62000.0
# Successfully Updated the 97 Option Type as : CALL
# Symbol Data 98 was Split Correctly : ['BTC', '27OCT24', '65000', 'C']
# Successfully Updated the 98 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 98 Strike Price as : 65000.0
# Successfully Updated the 98 Option Type as : CALL
# Symbol Data 99 was Split Correctly : ['BTC', '27OCT24', '64000', 'P']
# Successfully Updated the 99 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 99 Strike Price as : 64000.0
# Successfully Updated the 99 Option Type as : PUT
# Symbol Data 100 was Split Correctly : ['BTC', '27OCT24', '65500', 'P']
# Successfully Updated the 100 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 100 Strike Price as : 65500.0
# Successfully Updated the 100 Option Type as : PUT
# Symbol Data 101 was Split Correctly : ['BTC', '27OCT24', '65000', 'P']
# Successfully Updated the 101 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 101 Strike Price as : 65000.0
# Successfully Updated the 101 Option Type as : PUT
# Symbol Data 102 was Split Correctly : ['BTC', '27OCT24', '72000', 'P']
# Successfully Updated the 102 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 102 Strike Price as : 72000.0
# Successfully Updated the 102 Option Type as : PUT
# Symbol Data 103 was Split Correctly : ['BTC', '27OCT24', '69000', 'C']
# Successfully Updated the 103 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 103 Strike Price as : 69000.0
# Successfully Updated the 103 Option Type as : CALL
# Symbol Data 104 was Split Correctly : ['BTC', '27OCT24', '68000', 'C']
# Successfully Updated the 104 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 104 Strike Price as : 68000.0
# Successfully Updated the 104 Option Type as : CALL
# Symbol Data 105 was Split Correctly : ['BTC', '27OCT24', '73000', 'C']
# Successfully Updated the 105 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 105 Strike Price as : 73000.0
# Successfully Updated the 105 Option Type as : CALL
# Symbol Data 106 was Split Correctly : ['BTC', '27OCT24', '64000', 'C']
# Successfully Updated the 106 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 106 Strike Price as : 64000.0
# Successfully Updated the 106 Option Type as : CALL
# Symbol Data 107 was Split Correctly : ['BTC', '27OCT24', '69000', 'P']
# Successfully Updated the 107 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 107 Strike Price as : 69000.0
# Successfully Updated the 107 Option Type as : PUT
# Symbol Data 108 was Split Correctly : ['BTC', '27OCT24', '68500', 'C']
# Successfully Updated the 108 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 108 Strike Price as : 68500.0
# Successfully Updated the 108 Option Type as : CALL
# Symbol Data 109 was Split Correctly : ['BTC', '27OCT24', '69500', 'C']
# Successfully Updated the 109 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 109 Strike Price as : 69500.0
# Successfully Updated the 109 Option Type as : CALL
# Symbol Data 110 was Split Correctly : ['BTC', '27OCT24', '66000', 'P']
# Successfully Updated the 110 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 110 Strike Price as : 66000.0
# Successfully Updated the 110 Option Type as : PUT
# Symbol Data 111 was Split Correctly : ['BTC', '27OCT24', '72000', 'C']
# Successfully Updated the 111 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 111 Strike Price as : 72000.0
# Successfully Updated the 111 Option Type as : CALL
# Symbol Data 112 was Split Correctly : ['BTC', '27OCT24', '66500', 'P']
# Successfully Updated the 112 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 112 Strike Price as : 66500.0
# Successfully Updated the 112 Option Type as : PUT
# Symbol Data 113 was Split Correctly : ['BTC', '27OCT24', '68500', 'P']
# Successfully Updated the 113 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 113 Strike Price as : 68500.0
# Successfully Updated the 113 Option Type as : PUT
# Symbol Data 114 was Split Correctly : ['BTC', '27OCT24', '71000', 'P']
# Successfully Updated the 114 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 114 Strike Price as : 71000.0
# Successfully Updated the 114 Option Type as : PUT
# Symbol Data 115 was Split Correctly : ['BTC', '27OCT24', '69500', 'P']
# Successfully Updated the 115 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 115 Strike Price as : 69500.0
# Successfully Updated the 115 Option Type as : PUT
# Symbol Data 116 was Split Correctly : ['BTC', '27OCT24', '62000', 'P']
# Successfully Updated the 116 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 116 Strike Price as : 62000.0
# Successfully Updated the 116 Option Type as : PUT
# Symbol Data 117 was Split Correctly : ['BTC', '27OCT24', '70000', 'C']
# Successfully Updated the 117 Expiry Date  Type as : 2024-10-27
# Successfully Updated the 117 Strike Price as : 70000.0
# Successfully Updated the 117 Option Type as : CALL
# Symbol Data 118 was Split Correctly : ['BTC', '28MAR25', '70000', 'C']
# Successfully Updated the 118 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 118 Strike Price as : 70000.0
# Successfully Updated the 118 Option Type as : CALL
# Symbol Data 119 was Split Correctly : ['BTC', '28MAR25', '90000', 'C']
# Successfully Updated the 119 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 119 Strike Price as : 90000.0
# Successfully Updated the 119 Option Type as : CALL
# Symbol Data 120 was Split Correctly : ['BTC', '28MAR25', '200000', 'P']
# Successfully Updated the 120 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 120 Strike Price as : 200000.0
# Successfully Updated the 120 Option Type as : PUT
# Symbol Data 121 was Split Correctly : ['BTC', '28MAR25', '75000', 'P']
# Successfully Updated the 121 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 121 Strike Price as : 75000.0
# Successfully Updated the 121 Option Type as : PUT
# Symbol Data 122 was Split Correctly : ['BTC', '28MAR25', '100000', 'C']
# Successfully Updated the 122 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 122 Strike Price as : 100000.0
# Successfully Updated the 122 Option Type as : CALL
# Symbol Data 123 was Split Correctly : ['BTC', '28MAR25', '80000', 'C']
# Successfully Updated the 123 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 123 Strike Price as : 80000.0
# Successfully Updated the 123 Option Type as : CALL
# Symbol Data 124 was Split Correctly : ['BTC', '28MAR25', '95000', 'C']
# Successfully Updated the 124 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 124 Strike Price as : 95000.0
# Successfully Updated the 124 Option Type as : CALL
# Symbol Data 125 was Split Correctly : ['BTC', '28MAR25', '95000', 'P']
# Successfully Updated the 125 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 125 Strike Price as : 95000.0
# Successfully Updated the 125 Option Type as : PUT
# Symbol Data 126 was Split Correctly : ['BTC', '28MAR25', '75000', 'C']
# Successfully Updated the 126 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 126 Strike Price as : 75000.0
# Successfully Updated the 126 Option Type as : CALL
# Symbol Data 127 was Split Correctly : ['BTC', '28MAR25', '20000', 'C']
# Successfully Updated the 127 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 127 Strike Price as : 20000.0
# Successfully Updated the 127 Option Type as : CALL
# Symbol Data 128 was Split Correctly : ['BTC', '28MAR25', '110000', 'C']
# Successfully Updated the 128 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 128 Strike Price as : 110000.0
# Successfully Updated the 128 Option Type as : CALL
# Symbol Data 129 was Split Correctly : ['BTC', '28MAR25', '20000', 'P']
# Successfully Updated the 129 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 129 Strike Price as : 20000.0
# Successfully Updated the 129 Option Type as : PUT
# Symbol Data 130 was Split Correctly : ['BTC', '28MAR25', '220000', 'C']
# Successfully Updated the 130 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 130 Strike Price as : 220000.0
# Successfully Updated the 130 Option Type as : CALL
# Symbol Data 131 was Split Correctly : ['BTC', '28MAR25', '110000', 'P']
# Successfully Updated the 131 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 131 Strike Price as : 110000.0
# Successfully Updated the 131 Option Type as : PUT
# Symbol Data 132 was Split Correctly : ['BTC', '28MAR25', '40000', 'C']
# Successfully Updated the 132 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 132 Strike Price as : 40000.0
# Successfully Updated the 132 Option Type as : CALL
# Symbol Data 133 was Split Correctly : ['BTC', '28MAR25', '65000', 'P']
# Successfully Updated the 133 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 133 Strike Price as : 65000.0
# Successfully Updated the 133 Option Type as : PUT
# Symbol Data 134 was Split Correctly : ['BTC', '28MAR25', '240000', 'C']
# Successfully Updated the 134 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 134 Strike Price as : 240000.0
# Successfully Updated the 134 Option Type as : CALL
# Symbol Data 135 was Split Correctly : ['BTC', '28MAR25', '80000', 'P']
# Successfully Updated the 135 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 135 Strike Price as : 80000.0
# Successfully Updated the 135 Option Type as : PUT
# Symbol Data 136 was Split Correctly : ['BTC', '28MAR25', '120000', 'P']
# Successfully Updated the 136 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 136 Strike Price as : 120000.0
# Successfully Updated the 136 Option Type as : PUT
# Symbol Data 137 was Split Correctly : ['BTC', '28MAR25', '30000', 'C']
# Successfully Updated the 137 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 137 Strike Price as : 30000.0
# Successfully Updated the 137 Option Type as : CALL
# Symbol Data 138 was Split Correctly : ['BTC', '28MAR25', '220000', 'P']
# Successfully Updated the 138 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 138 Strike Price as : 220000.0
# Successfully Updated the 138 Option Type as : PUT
# Symbol Data 139 was Split Correctly : ['BTC', '28MAR25', '50000', 'C']
# Successfully Updated the 139 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 139 Strike Price as : 50000.0
# Successfully Updated the 139 Option Type as : CALL
# Symbol Data 140 was Split Correctly : ['BTC', '28MAR25', '30000', 'P']
# Successfully Updated the 140 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 140 Strike Price as : 30000.0
# Successfully Updated the 140 Option Type as : PUT
# Symbol Data 141 was Split Correctly : ['BTC', '28MAR25', '85000', 'C']
# Successfully Updated the 141 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 141 Strike Price as : 85000.0
# Successfully Updated the 141 Option Type as : CALL
# Symbol Data 142 was Split Correctly : ['BTC', '28MAR25', '40000', 'P']
# Successfully Updated the 142 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 142 Strike Price as : 40000.0
# Successfully Updated the 142 Option Type as : PUT
# Symbol Data 143 was Split Correctly : ['BTC', '28MAR25', '180000', 'C']
# Successfully Updated the 143 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 143 Strike Price as : 180000.0
# Successfully Updated the 143 Option Type as : CALL
# Symbol Data 144 was Split Correctly : ['BTC', '28MAR25', '130000', 'C']
# Successfully Updated the 144 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 144 Strike Price as : 130000.0
# Successfully Updated the 144 Option Type as : CALL
# Symbol Data 145 was Split Correctly : ['BTC', '28MAR25', '160000', 'C']
# Successfully Updated the 145 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 145 Strike Price as : 160000.0
# Successfully Updated the 145 Option Type as : CALL
# Symbol Data 146 was Split Correctly : ['BTC', '28MAR25', '130000', 'P']
# Successfully Updated the 146 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 146 Strike Price as : 130000.0
# Successfully Updated the 146 Option Type as : PUT
# Symbol Data 147 was Split Correctly : ['BTC', '28MAR25', '50000', 'P']
# Successfully Updated the 147 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 147 Strike Price as : 50000.0
# Successfully Updated the 147 Option Type as : PUT
# Symbol Data 148 was Split Correctly : ['BTC', '28MAR25', '60000', 'P']
# Successfully Updated the 148 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 148 Strike Price as : 60000.0
# Successfully Updated the 148 Option Type as : PUT
# Symbol Data 149 was Split Correctly : ['BTC', '28MAR25', '160000', 'P']
# Successfully Updated the 149 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 149 Strike Price as : 160000.0
# Successfully Updated the 149 Option Type as : PUT
# Symbol Data 150 was Split Correctly : ['BTC', '28MAR25', '140000', 'P']
# Successfully Updated the 150 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 150 Strike Price as : 140000.0
# Successfully Updated the 150 Option Type as : PUT
# Symbol Data 151 was Split Correctly : ['BTC', '28MAR25', '60000', 'C']
# Successfully Updated the 151 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 151 Strike Price as : 60000.0
# Successfully Updated the 151 Option Type as : CALL
# Symbol Data 152 was Split Correctly : ['BTC', '28MAR25', '70000', 'P']
# Successfully Updated the 152 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 152 Strike Price as : 70000.0
# Successfully Updated the 152 Option Type as : PUT
# Symbol Data 153 was Split Correctly : ['BTC', '28MAR25', '100000', 'P']
# Successfully Updated the 153 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 153 Strike Price as : 100000.0
# Successfully Updated the 153 Option Type as : PUT
# Symbol Data 154 was Split Correctly : ['BTC', '28MAR25', '140000', 'C']
# Successfully Updated the 154 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 154 Strike Price as : 140000.0
# Successfully Updated the 154 Option Type as : CALL
# Symbol Data 155 was Split Correctly : ['BTC', '28MAR25', '240000', 'P']
# Successfully Updated the 155 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 155 Strike Price as : 240000.0
# Successfully Updated the 155 Option Type as : PUT
# Symbol Data 156 was Split Correctly : ['BTC', '28MAR25', '200000', 'C']
# Successfully Updated the 156 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 156 Strike Price as : 200000.0
# Successfully Updated the 156 Option Type as : CALL
# Symbol Data 157 was Split Correctly : ['BTC', '28MAR25', '120000', 'C']
# Successfully Updated the 157 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 157 Strike Price as : 120000.0
# Successfully Updated the 157 Option Type as : CALL
# Symbol Data 158 was Split Correctly : ['BTC', '28MAR25', '85000', 'P']
# Successfully Updated the 158 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 158 Strike Price as : 85000.0
# Successfully Updated the 158 Option Type as : PUT
# Symbol Data 159 was Split Correctly : ['BTC', '28MAR25', '65000', 'C']
# Successfully Updated the 159 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 159 Strike Price as : 65000.0
# Successfully Updated the 159 Option Type as : CALL
# Symbol Data 160 was Split Correctly : ['BTC', '28MAR25', '180000', 'P']
# Successfully Updated the 160 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 160 Strike Price as : 180000.0
# Successfully Updated the 160 Option Type as : PUT
# Symbol Data 161 was Split Correctly : ['BTC', '28MAR25', '90000', 'P']
# Successfully Updated the 161 Expiry Date  Type as : 2025-03-28
# Successfully Updated the 161 Strike Price as : 90000.0
# Successfully Updated the 161 Option Type as : PUT
# Symbol Data 162 was Split Correctly : ['BTC', '28OCT24', '68500', 'P']
# Successfully Updated the 162 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 162 Strike Price as : 68500.0
# Successfully Updated the 162 Option Type as : PUT
# Symbol Data 163 was Split Correctly : ['BTC', '28OCT24', '65000', 'P']
# Successfully Updated the 163 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 163 Strike Price as : 65000.0
# Successfully Updated the 163 Option Type as : PUT
# Symbol Data 164 was Split Correctly : ['BTC', '28OCT24', '65000', 'C']
# Successfully Updated the 164 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 164 Strike Price as : 65000.0
# Successfully Updated the 164 Option Type as : CALL
# Symbol Data 165 was Split Correctly : ['BTC', '28OCT24', '64000', 'P']
# Successfully Updated the 165 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 165 Strike Price as : 64000.0
# Successfully Updated the 165 Option Type as : PUT
# Symbol Data 166 was Split Correctly : ['BTC', '28OCT24', '66000', 'P']
# Successfully Updated the 166 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 166 Strike Price as : 66000.0
# Successfully Updated the 166 Option Type as : PUT
# Symbol Data 167 was Split Correctly : ['BTC', '28OCT24', '72000', 'C']
# Successfully Updated the 167 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 167 Strike Price as : 72000.0
# Successfully Updated the 167 Option Type as : CALL
# Symbol Data 168 was Split Correctly : ['BTC', '28OCT24', '73000', 'C']
# Successfully Updated the 168 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 168 Strike Price as : 73000.0
# Successfully Updated the 168 Option Type as : CALL
# Symbol Data 169 was Split Correctly : ['BTC', '28OCT24', '66000', 'C']
# Successfully Updated the 169 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 169 Strike Price as : 66000.0
# Successfully Updated the 169 Option Type as : CALL
# Symbol Data 170 was Split Correctly : ['BTC', '28OCT24', '66500', 'C']
# Successfully Updated the 170 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 170 Strike Price as : 66500.0
# Successfully Updated the 170 Option Type as : CALL
# Symbol Data 171 was Split Correctly : ['BTC', '28OCT24', '65500', 'C']
# Successfully Updated the 171 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 171 Strike Price as : 65500.0
# Successfully Updated the 171 Option Type as : CALL
# Symbol Data 172 was Split Correctly : ['BTC', '28OCT24', '67000', 'C']
# Successfully Updated the 172 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 172 Strike Price as : 67000.0
# Successfully Updated the 172 Option Type as : CALL
# Symbol Data 173 was Split Correctly : ['BTC', '28OCT24', '62000', 'P']
# Successfully Updated the 173 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 173 Strike Price as : 62000.0
# Successfully Updated the 173 Option Type as : PUT
# Symbol Data 174 was Split Correctly : ['BTC', '28OCT24', '63000', 'C']
# Successfully Updated the 174 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 174 Strike Price as : 63000.0
# Successfully Updated the 174 Option Type as : CALL
# Symbol Data 175 was Split Correctly : ['BTC', '28OCT24', '70000', 'P']
# Successfully Updated the 175 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 175 Strike Price as : 70000.0
# Successfully Updated the 175 Option Type as : PUT
# Symbol Data 176 was Split Correctly : ['BTC', '28OCT24', '73000', 'P']
# Successfully Updated the 176 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 176 Strike Price as : 73000.0
# Successfully Updated the 176 Option Type as : PUT
# Symbol Data 177 was Split Correctly : ['BTC', '28OCT24', '64000', 'C']
# Successfully Updated the 177 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 177 Strike Price as : 64000.0
# Successfully Updated the 177 Option Type as : CALL
# Symbol Data 178 was Split Correctly : ['BTC', '28OCT24', '67500', 'P']
# Successfully Updated the 178 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 178 Strike Price as : 67500.0
# Successfully Updated the 178 Option Type as : PUT
# Symbol Data 179 was Split Correctly : ['BTC', '28OCT24', '67000', 'P']
# Successfully Updated the 179 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 179 Strike Price as : 67000.0
# Successfully Updated the 179 Option Type as : PUT
# Symbol Data 180 was Split Correctly : ['BTC', '28OCT24', '69500', 'P']
# Successfully Updated the 180 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 180 Strike Price as : 69500.0
# Successfully Updated the 180 Option Type as : PUT
# Symbol Data 181 was Split Correctly : ['BTC', '28OCT24', '68500', 'C']
# Successfully Updated the 181 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 181 Strike Price as : 68500.0
# Successfully Updated the 181 Option Type as : CALL
# Symbol Data 182 was Split Correctly : ['BTC', '28OCT24', '71000', 'P']
# Successfully Updated the 182 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 182 Strike Price as : 71000.0
# Successfully Updated the 182 Option Type as : PUT
# Symbol Data 183 was Split Correctly : ['BTC', '28OCT24', '70000', 'C']
# Successfully Updated the 183 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 183 Strike Price as : 70000.0
# Successfully Updated the 183 Option Type as : CALL
# Symbol Data 184 was Split Correctly : ['BTC', '28OCT24', '72000', 'P']
# Successfully Updated the 184 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 184 Strike Price as : 72000.0
# Successfully Updated the 184 Option Type as : PUT
# Symbol Data 185 was Split Correctly : ['BTC', '28OCT24', '69500', 'C']
# Successfully Updated the 185 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 185 Strike Price as : 69500.0
# Successfully Updated the 185 Option Type as : CALL
# Symbol Data 186 was Split Correctly : ['BTC', '28OCT24', '69000', 'P']
# Successfully Updated the 186 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 186 Strike Price as : 69000.0
# Successfully Updated the 186 Option Type as : PUT
# Symbol Data 187 was Split Correctly : ['BTC', '28OCT24', '68000', 'C']
# Successfully Updated the 187 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 187 Strike Price as : 68000.0
# Successfully Updated the 187 Option Type as : CALL
# Symbol Data 188 was Split Correctly : ['BTC', '28OCT24', '63000', 'P']
# Successfully Updated the 188 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 188 Strike Price as : 63000.0
# Successfully Updated the 188 Option Type as : PUT
# Symbol Data 189 was Split Correctly : ['BTC', '28OCT24', '71000', 'C']
# Successfully Updated the 189 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 189 Strike Price as : 71000.0
# Successfully Updated the 189 Option Type as : CALL
# Symbol Data 190 was Split Correctly : ['BTC', '28OCT24', '67500', 'C']
# Successfully Updated the 190 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 190 Strike Price as : 67500.0
# Successfully Updated the 190 Option Type as : CALL
# Symbol Data 191 was Split Correctly : ['BTC', '28OCT24', '66500', 'P']
# Successfully Updated the 191 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 191 Strike Price as : 66500.0
# Successfully Updated the 191 Option Type as : PUT
# Symbol Data 192 was Split Correctly : ['BTC', '28OCT24', '62000', 'C']
# Successfully Updated the 192 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 192 Strike Price as : 62000.0
# Successfully Updated the 192 Option Type as : CALL
# Symbol Data 193 was Split Correctly : ['BTC', '28OCT24', '65500', 'P']
# Successfully Updated the 193 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 193 Strike Price as : 65500.0
# Successfully Updated the 193 Option Type as : PUT
# Symbol Data 194 was Split Correctly : ['BTC', '28OCT24', '69000', 'C']
# Successfully Updated the 194 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 194 Strike Price as : 69000.0
# Successfully Updated the 194 Option Type as : CALL
# Symbol Data 195 was Split Correctly : ['BTC', '28OCT24', '68000', 'P']
# Successfully Updated the 195 Expiry Date  Type as : 2024-10-28
# Successfully Updated the 195 Strike Price as : 68000.0
# Successfully Updated the 195 Option Type as : PUT
# Symbol Data 196 was Split Correctly : ['BTC', '15NOV24', '64000', 'C']
# Successfully Updated the 196 Expiry Date  Type as : 2024-11-15
# Successfully Updated the 196 Strike Price as : 64000.0
# Successfully Updated the 196 Option Type as : CALL
# Symbol Data 197 was Split Correctly : ['BTC', '15NOV24', '76000', 'C']
# Successfully Updated the 197 Expiry Date  Type as : 2024-11-15
# Successfully Updated the 197 Strike Price as : 76000.0
# Successfully Updated the 197 Option Type as : CALL
# Symbol Data 198 was Split Correctly : ['BTC', '15NOV24', '54000', 'P']
# Successfully Updated the 198 Expiry Date  Type as : 2024-11-15
# Successfully Updated the 198 Strike Price as : 54000.0
# Successfully Updated the 198 Option Type as : PUT
# Symbol Data 199 was Split Correctly : ['BTC', '15NOV24', '84000', 'C']
# Successfully Updated the 199 Expiry Date  Type as : 2024-11-15
# Successfully Updated the 199 Strike Price as : 84000.0
# Successfully Updated the 199 Option Type as : CALL
# Symbol Data 200 was Split Correctly : ['BTC', '15NOV24', '70000', 'P']
# Successfully Updated the 200 Expiry Date  Type as : 2024-11-15
# Successfully Updated the 200 Strike Price as : 70000.0
# Successfully Updated the 200 Option Type as : PUT
# Symbol Data 201 was Split Correctly : ['BTC', '15NOV24', '84000', 'P']
# Successfully Updated the 201 Expiry Date  Type as : 2024-11-15
# Successfully Updated the 201 Strike Price as : 84000.0
# ...
# Successfully Updated the 453 Strike Price as : 48000.0
# Successfully Updated the 453 Option Type as : PUT
# Symbol Data 454 was Split Correctly : ['BTC', '29NOV24', '61000', 'P']
# Successfully Updated the 454 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 454 Strike Price as : 61000.0
# Successfully Updated the 454 Option Type as : PUT
# Symbol Data 455 was Split Correctly : ['BTC', '29NOV24', '50000', 'C']
# Successfully Updated the 455 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 455 Strike Price as : 50000.0
# Successfully Updated the 455 Option Type as : CALL
# Symbol Data 456 was Split Correctly : ['BTC', '29NOV24', '92000', 'C']
# Successfully Updated the 456 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 456 Strike Price as : 92000.0
# Successfully Updated the 456 Option Type as : CALL
# Symbol Data 457 was Split Correctly : ['BTC', '29NOV24', '94000', 'P']
# Successfully Updated the 457 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 457 Strike Price as : 94000.0
# Successfully Updated the 457 Option Type as : PUT
# Symbol Data 458 was Split Correctly : ['BTC', '29NOV24', '80000', 'C']
# Successfully Updated the 458 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 458 Strike Price as : 80000.0
# Successfully Updated the 458 Option Type as : CALL
# Symbol Data 459 was Split Correctly : ['BTC', '29NOV24', '65000', 'P']
# Successfully Updated the 459 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 459 Strike Price as : 65000.0
# Successfully Updated the 459 Option Type as : PUT
# Symbol Data 460 was Split Correctly : ['BTC', '29NOV24', '44000', 'C']
# Successfully Updated the 460 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 460 Strike Price as : 44000.0
# Successfully Updated the 460 Option Type as : CALL
# Symbol Data 461 was Split Correctly : ['BTC', '29NOV24', '71000', 'P']
# Successfully Updated the 461 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 461 Strike Price as : 71000.0
# Successfully Updated the 461 Option Type as : PUT
# Symbol Data 462 was Split Correctly : ['BTC', '29NOV24', '82000', 'C']
# Successfully Updated the 462 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 462 Strike Price as : 82000.0
# Successfully Updated the 462 Option Type as : CALL
# Symbol Data 463 was Split Correctly : ['BTC', '29NOV24', '88000', 'P']
# Successfully Updated the 463 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 463 Strike Price as : 88000.0
# Successfully Updated the 463 Option Type as : PUT
# Symbol Data 464 was Split Correctly : ['BTC', '29NOV24', '56000', 'C']
# Successfully Updated the 464 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 464 Strike Price as : 56000.0
# Successfully Updated the 464 Option Type as : CALL
# Symbol Data 465 was Split Correctly : ['BTC', '29NOV24', '60000', 'C']
# Successfully Updated the 465 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 465 Strike Price as : 60000.0
# Successfully Updated the 465 Option Type as : CALL
# Symbol Data 466 was Split Correctly : ['BTC', '29NOV24', '36000', 'C']
# Successfully Updated the 466 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 466 Strike Price as : 36000.0
# Successfully Updated the 466 Option Type as : CALL
# Symbol Data 467 was Split Correctly : ['BTC', '29NOV24', '61000', 'C']
# Successfully Updated the 467 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 467 Strike Price as : 61000.0
# Successfully Updated the 467 Option Type as : CALL
# Symbol Data 468 was Split Correctly : ['BTC', '29NOV24', '48000', 'C']
# Successfully Updated the 468 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 468 Strike Price as : 48000.0
# Successfully Updated the 468 Option Type as : CALL
# Symbol Data 469 was Split Correctly : ['BTC', '29NOV24', '84000', 'C']
# Successfully Updated the 469 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 469 Strike Price as : 84000.0
# Successfully Updated the 469 Option Type as : CALL
# Symbol Data 470 was Split Correctly : ['BTC', '29NOV24', '94000', 'C']
# Successfully Updated the 470 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 470 Strike Price as : 94000.0
# Successfully Updated the 470 Option Type as : CALL
# Symbol Data 471 was Split Correctly : ['BTC', '29NOV24', '56000', 'P']
# Successfully Updated the 471 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 471 Strike Price as : 56000.0
# Successfully Updated the 471 Option Type as : PUT
# Symbol Data 472 was Split Correctly : ['BTC', '29NOV24', '42000', 'C']
# Successfully Updated the 472 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 472 Strike Price as : 42000.0
# Successfully Updated the 472 Option Type as : CALL
# Symbol Data 473 was Split Correctly : ['BTC', '29NOV24', '71000', 'C']
# Successfully Updated the 473 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 473 Strike Price as : 71000.0
# Successfully Updated the 473 Option Type as : CALL
# Symbol Data 474 was Split Correctly : ['BTC', '29NOV24', '82000', 'P']
# Successfully Updated the 474 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 474 Strike Price as : 82000.0
# Successfully Updated the 474 Option Type as : PUT
# Symbol Data 475 was Split Correctly : ['BTC', '29NOV24', '75000', 'P']
# Successfully Updated the 475 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 475 Strike Price as : 75000.0
# Successfully Updated the 475 Option Type as : PUT
# Symbol Data 476 was Split Correctly : ['BTC', '29NOV24', '84000', 'P']
# Successfully Updated the 476 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 476 Strike Price as : 84000.0
# Successfully Updated the 476 Option Type as : PUT
# Symbol Data 477 was Split Correctly : ['BTC', '29NOV24', '59000', 'P']
# Successfully Updated the 477 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 477 Strike Price as : 59000.0
# Successfully Updated the 477 Option Type as : PUT
# Symbol Data 478 was Split Correctly : ['BTC', '29NOV24', '65000', 'C']
# Successfully Updated the 478 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 478 Strike Price as : 65000.0
# Successfully Updated the 478 Option Type as : CALL
# Symbol Data 479 was Split Correctly : ['BTC', '29NOV24', '46000', 'C']
# Successfully Updated the 479 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 479 Strike Price as : 46000.0
# Successfully Updated the 479 Option Type as : CALL
# Symbol Data 480 was Split Correctly : ['BTC', '29NOV24', '92000', 'P']
# Successfully Updated the 480 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 480 Strike Price as : 92000.0
# Successfully Updated the 480 Option Type as : PUT
# Symbol Data 481 was Split Correctly : ['BTC', '29NOV24', '76000', 'P']
# Successfully Updated the 481 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 481 Strike Price as : 76000.0
# Successfully Updated the 481 Option Type as : PUT
# Symbol Data 482 was Split Correctly : ['BTC', '29NOV24', '60000', 'P']
# Successfully Updated the 482 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 482 Strike Price as : 60000.0
# Successfully Updated the 482 Option Type as : PUT
# Symbol Data 483 was Split Correctly : ['BTC', '29NOV24', '58000', 'P']
# Successfully Updated the 483 Expiry Date  Type as : 2024-11-29
# Successfully Updated the 483 Strike Price as : 58000.0
# Successfully Updated the 483 Option Type as : PUT
# Symbol Data 484 was Split Correctly : ['BTC', '27JUN25', '60000', 'P']
# Successfully Updated the 484 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 484 Strike Price as : 60000.0
# Successfully Updated the 484 Option Type as : PUT
# Symbol Data 485 was Split Correctly : ['BTC', '27JUN25', '300000', 'P']
# Successfully Updated the 485 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 485 Strike Price as : 300000.0
# Successfully Updated the 485 Option Type as : PUT
# Symbol Data 486 was Split Correctly : ['BTC', '27JUN25', '90000', 'C']
# Successfully Updated the 486 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 486 Strike Price as : 90000.0
# Successfully Updated the 486 Option Type as : CALL
# Symbol Data 487 was Split Correctly : ['BTC', '27JUN25', '160000', 'P']
# Successfully Updated the 487 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 487 Strike Price as : 160000.0
# Successfully Updated the 487 Option Type as : PUT
# Symbol Data 488 was Split Correctly : ['BTC', '27JUN25', '140000', 'C']
# Successfully Updated the 488 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 488 Strike Price as : 140000.0
# Successfully Updated the 488 Option Type as : CALL
# Symbol Data 489 was Split Correctly : ['BTC', '27JUN25', '20000', 'C']
# Successfully Updated the 489 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 489 Strike Price as : 20000.0
# Successfully Updated the 489 Option Type as : CALL
# Symbol Data 490 was Split Correctly : ['BTC', '27JUN25', '50000', 'P']
# Successfully Updated the 490 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 490 Strike Price as : 50000.0
# Successfully Updated the 490 Option Type as : PUT
# Symbol Data 491 was Split Correctly : ['BTC', '27JUN25', '50000', 'C']
# Successfully Updated the 491 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 491 Strike Price as : 50000.0
# Successfully Updated the 491 Option Type as : CALL
# Symbol Data 492 was Split Correctly : ['BTC', '27JUN25', '80000', 'P']
# Successfully Updated the 492 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 492 Strike Price as : 80000.0
# Successfully Updated the 492 Option Type as : PUT
# Symbol Data 493 was Split Correctly : ['BTC', '27JUN25', '250000', 'P']
# Successfully Updated the 493 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 493 Strike Price as : 250000.0
# Successfully Updated the 493 Option Type as : PUT
# Symbol Data 494 was Split Correctly : ['BTC', '27JUN25', '40000', 'P']
# Successfully Updated the 494 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 494 Strike Price as : 40000.0
# Successfully Updated the 494 Option Type as : PUT
# Symbol Data 495 was Split Correctly : ['BTC', '27JUN25', '80000', 'C']
# Successfully Updated the 495 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 495 Strike Price as : 80000.0
# Successfully Updated the 495 Option Type as : CALL
# Symbol Data 496 was Split Correctly : ['BTC', '27JUN25', '110000', 'P']
# Successfully Updated the 496 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 496 Strike Price as : 110000.0
# Successfully Updated the 496 Option Type as : PUT
# Symbol Data 497 was Split Correctly : ['BTC', '27JUN25', '75000', 'P']
# Successfully Updated the 497 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 497 Strike Price as : 75000.0
# Successfully Updated the 497 Option Type as : PUT
# Symbol Data 498 was Split Correctly : ['BTC', '27JUN25', '200000', 'C']
# Successfully Updated the 498 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 498 Strike Price as : 200000.0
# Successfully Updated the 498 Option Type as : CALL
# Symbol Data 499 was Split Correctly : ['BTC', '27JUN25', '70000', 'C']
# Successfully Updated the 499 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 499 Strike Price as : 70000.0
# Successfully Updated the 499 Option Type as : CALL
# Symbol Data 500 was Split Correctly : ['BTC', '27JUN25', '75000', 'C']
# Successfully Updated the 500 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 500 Strike Price as : 75000.0
# Successfully Updated the 500 Option Type as : CALL
# Symbol Data 501 was Split Correctly : ['BTC', '27JUN25', '120000', 'P']
# Successfully Updated the 501 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 501 Strike Price as : 120000.0
# Successfully Updated the 501 Option Type as : PUT
# Symbol Data 502 was Split Correctly : ['BTC', '27JUN25', '180000', 'P']
# Successfully Updated the 502 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 502 Strike Price as : 180000.0
# Successfully Updated the 502 Option Type as : PUT
# Symbol Data 503 was Split Correctly : ['BTC', '27JUN25', '90000', 'P']
# Successfully Updated the 503 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 503 Strike Price as : 90000.0
# Successfully Updated the 503 Option Type as : PUT
# Symbol Data 504 was Split Correctly : ['BTC', '27JUN25', '300000', 'C']
# Successfully Updated the 504 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 504 Strike Price as : 300000.0
# Successfully Updated the 504 Option Type as : CALL
# Symbol Data 505 was Split Correctly : ['BTC', '27JUN25', '65000', 'C']
# Successfully Updated the 505 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 505 Strike Price as : 65000.0
# Successfully Updated the 505 Option Type as : CALL
# Symbol Data 506 was Split Correctly : ['BTC', '27JUN25', '180000', 'C']
# Successfully Updated the 506 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 506 Strike Price as : 180000.0
# Successfully Updated the 506 Option Type as : CALL
# Symbol Data 507 was Split Correctly : ['BTC', '27JUN25', '40000', 'C']
# Successfully Updated the 507 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 507 Strike Price as : 40000.0
# Successfully Updated the 507 Option Type as : CALL
# Symbol Data 508 was Split Correctly : ['BTC', '27JUN25', '200000', 'P']
# Successfully Updated the 508 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 508 Strike Price as : 200000.0
# Successfully Updated the 508 Option Type as : PUT
# Symbol Data 509 was Split Correctly : ['BTC', '27JUN25', '110000', 'C']
# Successfully Updated the 509 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 509 Strike Price as : 110000.0
# Successfully Updated the 509 Option Type as : CALL
# Symbol Data 510 was Split Correctly : ['BTC', '27JUN25', '100000', 'P']
# Successfully Updated the 510 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 510 Strike Price as : 100000.0
# Successfully Updated the 510 Option Type as : PUT
# Symbol Data 511 was Split Correctly : ['BTC', '27JUN25', '160000', 'C']
# Successfully Updated the 511 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 511 Strike Price as : 160000.0
# Successfully Updated the 511 Option Type as : CALL
# Symbol Data 512 was Split Correctly : ['BTC', '27JUN25', '140000', 'P']
# Successfully Updated the 512 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 512 Strike Price as : 140000.0
# Successfully Updated the 512 Option Type as : PUT
# Symbol Data 513 was Split Correctly : ['BTC', '27JUN25', '70000', 'P']
# Successfully Updated the 513 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 513 Strike Price as : 70000.0
# Successfully Updated the 513 Option Type as : PUT
# Symbol Data 514 was Split Correctly : ['BTC', '27JUN25', '60000', 'C']
# Successfully Updated the 514 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 514 Strike Price as : 60000.0
# Successfully Updated the 514 Option Type as : CALL
# Symbol Data 515 was Split Correctly : ['BTC', '27JUN25', '120000', 'C']
# Successfully Updated the 515 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 515 Strike Price as : 120000.0
# Successfully Updated the 515 Option Type as : CALL
# Symbol Data 516 was Split Correctly : ['BTC', '27JUN25', '100000', 'C']
# Successfully Updated the 516 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 516 Strike Price as : 100000.0
# Successfully Updated the 516 Option Type as : CALL
# Symbol Data 517 was Split Correctly : ['BTC', '27JUN25', '65000', 'P']
# Successfully Updated the 517 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 517 Strike Price as : 65000.0
# Successfully Updated the 517 Option Type as : PUT
# Symbol Data 518 was Split Correctly : ['BTC', '27JUN25', '250000', 'C']
# Successfully Updated the 518 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 518 Strike Price as : 250000.0
# Successfully Updated the 518 Option Type as : CALL
# Symbol Data 519 was Split Correctly : ['BTC', '27JUN25', '20000', 'P']
# Successfully Updated the 519 Expiry Date  Type as : 2025-06-27
# Successfully Updated the 519 Strike Price as : 20000.0
# Successfully Updated the 519 Option Type as : PUT

# %%
dataframe['option_type'] = option_type

# Merge the Numpy Array of "Strike_Price" with Primary DataFrame
dataframe['strike_price'] = strike_price

# Merge the Numpy Array of "Expiry Dates" with Primary DataFrame
dataframe['expiry'] = expiry

# Confirm the dtype of the Primary DataFrame Column "option_type" as String Object
dataframe['option_type'] = dataframe['option_type'].astype(dtype="string")

# Confirm the dtype of the Primary DataFrame Column "strike_price" as Float64 Object
dataframe['strike_price'] = dataframe['strike_price'].astype(dtype="float64")

# Confirm the dtype of the Primary DataFrame Column "expiry" as DataTime Object in Specific Date Format
# TODO: Removing the DateTime Conversion so that we can process the filtering using it as Object Variable
# TODO: To Process this Object we need always change the Field into Numpy Array then test for validation
dataframe['expiry'] = pd.to_datetime(dataframe['expiry'], format='%y%m%d')

# Sort the DataFrame using the Column "expiry" & "strike_price" in ascending Order Permanently
dataframe.sort_values(by=["expiry", "strike_price"], ascending=True, inplace=True)

# Convert the "Symbol" Column into DataFrame Index, then Drop the Duplicate "Symbol" Column Permanently
# self.dataframe.set_index(keys='symbol', drop=True, inplace=True)
# Don't Drop "symbol" key as it's required in the Order management, so replacing drop=True to False
dataframe.set_index(keys='symbol', drop=False, inplace=True)

end = time.perf_counter()
print(f"Formatting & Processing of DataFrame is Completed in : {(end - start) * 10 ** 3} ms \n")
# Out:
# Formatting & Processing of DataFrame is Completed in : 3919.4835819944274 ms

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 520 entries, BTC-26OCT24-61000-C to BTC-26SEP25-300000-C
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   symbol                  520 non-null    string
#  1   bid1Price               520 non-null    float64
#  2   bid1Size                520 non-null    float64
#  3   bid1Iv                  520 non-null    float64
#  4   ask1Price               520 non-null    float64
#  5   ask1Size                520 non-null    float64
#  6   ask1Iv                  520 non-null    float64
#  7   lastPrice               520 non-null    float64
#  8   highPrice24h            520 non-null    float64
#  9   lowPrice24h             520 non-null    float64
#  10  markPrice               520 non-null    float64
#  11  indexPrice              520 non-null    float64
#  12  markIv                  520 non-null    float64
#  13  underlyingPrice         520 non-null    float64
#  14  openInterest            520 non-null    float64
#  15  turnover24h             520 non-null    float64
#  16  volume24h               520 non-null    float64
#  17  totalVolume             520 non-null    float64
#  18  totalTurnover           520 non-null    float64
#  19  delta                   520 non-null    float64
#  20  gamma                   520 non-null    float64
#  21  vega                    520 non-null    float64
#  22  theta                   520 non-null    float64
#  23  predictedDeliveryPrice  520 non-null    float64
#  24  change24h               520 non-null    float64
#  25  option_type             520 non-null    string
#  26  strike_price            520 non-null    float64
#  27  expiry                  520 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(25), string(2)
# memory usage: 117.8 KB

# %% [markdown]
# ### Options Expiry Segregation

# %%
# Extracting Expiry Dates from the Primary DataFrame Object
expiry_dates = dataframe['expiry'].drop_duplicates().sort_values().copy()

# %%
expiry_dates
# Out:
# symbol
# BTC-26OCT24-61000-C   2024-10-26
# BTC-27OCT24-62000-C   2024-10-27
# BTC-28OCT24-62000-P   2024-10-28
# BTC-1NOV24-48000-C    2024-11-01
# BTC-8NOV24-44000-P    2024-11-08
# BTC-15NOV24-54000-P   2024-11-15
# BTC-29NOV24-32000-P   2024-11-29
# BTC-27DEC24-15000-P   2024-12-27
# BTC-28MAR25-20000-C   2025-03-28
# BTC-27JUN25-20000-C   2025-06-27
# BTC-26SEP25-20000-P   2025-09-26
# Name: expiry, dtype: datetime64[ns]

# %%
from src.common_functions import generate_expiry_dates
weekly_expiry_dates, monthly_expiry_dates, quarterly_expiry_dates = (generate_expiry_dates(weekly_count=5,
                                                                                           monthly_count=4,
                                                                                           quarterly_count=5))
# Out:
# Initial Current Month is  11
# Original Length of Weekly Expiry List Array : 67, But Length of returned Array : 5
# Original Length of Monthly Expiry List Array : 20, But Length of returned Array : 4
# Original Length of Weekly Expiry List Array : 6, But Length of returned Array : 5

# %%
exist: bool = False
expiry_date = None

expiry: dict = {
    "daily": {
        "delta_limit": None,
        "current": {
            "date": None,
            "exist": False,
            "position_exist": False,
            "symbol_list": []
        },
        "next": {
            "date": None,
            "exist": False,
            "position_exist": False,
            "symbol_list": []
        },
        "next_to_next": {
            "date": None,
            "exist": False,
            "position_exist": False,
            "symbol_list": []
        },
    },
    "weekly": {
        "delta_limit": None,
        "current": {
            "date": None,
            "exist": False,
            "position_exist": False,
            "symbol_list": []
        },
        "next": {
            "date": None,
            "exist": False,
            "position_exist": False,
            "symbol_list": []
        },
        "next_to_next": {
            "date": None,
            "exist": False,
            "position_exist": False,
            "symbol_list": []
        },
    },
    "monthly": {
        "delta_limit": None,
        "current": {
            "date": None,
            "exist": False,
            "position_exist": False,
            "symbol_list": []
        },
        "next": {
            "date": None,
            "exist": False,
            "position_exist": False,
            "symbol_list": []
        },
        "next_to_next": {
            "date": None,
            "exist": False,
            "position_exist": False,
            "symbol_list": []
        },
    },
    "quarterly": {
        "delta_limit": None,
        "current": {
            "date": None,
            "exist": False,
            "position_exist": False,
            "symbol_list": []
        },
        "next": {
            "date": None,
            "exist": False,
            "position_exist": False,
            "symbol_list": []
        },
        "next_to_next": {
            "date": None,
            "exist": False,
            "position_exist": False,
            "symbol_list": []
        },
    }
}

# %%
weekly_expiry_dates
# Out:
# [datetime.date(2024, 11, 1),
#  datetime.date(2024, 11, 8),
#  datetime.date(2024, 11, 15),
#  datetime.date(2024, 11, 22),
#  datetime.date(2024, 12, 6)]

# %%
expiry_list: list = []
for i in range(len(expiry_dates)):
    expiry_list.append(expiry_dates.iloc[i].date())
    print(f"{expiry_dates.iloc[i].date()}")
# Out:
# 2024-10-26
# 2024-10-27
# 2024-10-28
# 2024-11-01
# 2024-11-08
# 2024-11-15
# 2024-11-29
# 2024-12-27
# 2025-03-28
# 2025-06-27
# 2025-09-26

# %%
expiry_dates.iloc[3].date() in weekly_expiry_dates, expiry_dates.iloc[3].date(), weekly_expiry_dates
# Out:
# (True,
#  datetime.date(2024, 11, 1),
#  [datetime.date(2024, 11, 1),
#   datetime.date(2024, 11, 8),
#   datetime.date(2024, 11, 15),
#   datetime.date(2024, 11, 22),
#   datetime.date(2024, 12, 6)])

# %%
for i in range(len(expiry_dates)):
    if expiry_dates.iloc[i].date() in weekly_expiry_dates:
        if expiry["weekly"]["current"]["date"] is None:
            expiry["weekly"]["current"]["date"] = expiry_dates.iloc[i].date()
            expiry["weekly"]["current"]["exist"] = True
            print(f"Setting expiry[weekly][current][date] as : "
                  f"{expiry["weekly"]["current"]["date"]}",
                  f"Setting expiry[weekly][current][exist] as : "
                  f"{expiry["weekly"]["current"]["exist"]}")

        elif expiry["weekly"]["next"]["date"] is None:
            expiry["weekly"]["next"]["date"] = expiry_dates.iloc[i].date()
            expiry["weekly"]["next"]["exist"] = True
            print(f"Setting expiry[weekly][next][date] as : "
                  f"{expiry["weekly"]["next"]["date"]}",
                  f"Setting expiry[weekly][next][exist] as : "
                  f"{expiry["weekly"]["next"]["exist"]}")

        
        elif expiry["weekly"]["next_to_next"]["date"] is None:
            expiry["weekly"]["next_to_next"]["date"] = expiry_dates.iloc[i].date()
            expiry["weekly"]["next_to_next"]["exist"] = True
            print(f"Setting expiry[weekly][next_to_next][date] as : "
                  f"{expiry["weekly"]["next_to_next"]["date"]}",
                  f"Setting expiry[weekly][next_to_next][exist] as : "
                  f"{expiry["weekly"]["next_to_next"]["exist"]}")

    elif expiry_dates.iloc[i].date() in monthly_expiry_dates:
        if expiry["monthly"]["current"]["date"] is None:
            expiry["monthly"]["current"]["date"] = expiry_dates.iloc[i].date()
            expiry["monthly"]["current"]["exist"] = True
            print(f"Setting expiry[monthly][current][date] as : "
                  f"{expiry["monthly"]["current"]["date"]}",
                  f"Setting expiry[monthly][current][exist] as : "
                  f"{expiry["monthly"]["current"]["exist"]}")
        
        
        elif expiry["monthly"]["next"]["date"] is None:
            expiry["monthly"]["next"]["date"] = expiry_dates.iloc[i].date()
            expiry["monthly"]["next"]["exist"] = True
            print(f"Setting expiry[monthly][next][date] as : "
                  f"{expiry["monthly"]["next"]["date"]}",
                  f"Setting expiry[monthly][next][exist] as : "
                  f"{expiry["monthly"]["next"]["exist"]}")

        elif expiry["monthly"]["next_to_next"]["date"] is None:
            expiry["monthly"]["next_to_next"]["date"] = expiry_dates.iloc[i].date()
            expiry["monthly"]["next_to_next"]["exist"] = True
            print(f"Setting expiry[monthly][next_to_next][date] as : "
                  f"{expiry["monthly"]["next_to_next"]["date"]}",
                  f"Setting expiry[monthly][next_to_next][exist] as : "
                  f"{expiry["monthly"]["next_to_next"]["exist"]}")
            
    elif expiry_dates.iloc[i].date() in quarterly_expiry_dates:

        if expiry["quarterly"]["current"]["date"] is None:
            expiry["quarterly"]["current"]["date"] = expiry_dates.iloc[i].date()
            expiry["quarterly"]["current"]["exist"] = True
            print(f"Setting expiry[quarterly][current][date] as : "
                  f"{expiry["quarterly"]["current"]["date"]}",
                  f"Setting expiry[quarterly][current][exist] as : "
                  f"{expiry["quarterly"]["current"]["exist"]}")
        
        elif expiry["quarterly"]["next"]["date"] is None:
            expiry["quarterly"]["next"]["date"] = expiry_dates.iloc[i].date()
            expiry["quarterly"]["next"]["exist"] = True
            print(f"Setting expiry[quarterly][next][date] as : "
                  f"{expiry["quarterly"]["next"]["date"]}",
                  f"Setting expiry[quarterly][next][exist] as : "
                  f"{expiry["quarterly"]["next"]["exist"]}")
            
        elif expiry["quarterly"]["next_to_next"]["date"] is None:
            expiry["quarterly"]["next_to_next"]["date"] = expiry_dates.iloc[i].date()
            expiry["quarterly"]["next_to_next"]["exist"] = True
            print(f"Setting expiry[quarterly][next_to_next][date] as : "
                  f"{expiry["quarterly"]["next_to_next"]["date"]}",
                  f"Setting expiry[quarterly][next_to_next][exist] as : "
                  f"{expiry["quarterly"]["next_to_next"]["exist"]}")
# Out:
# Setting expiry[weekly][current][date] as : 2024-11-01 Setting expiry[weekly][current][exist] as : True
# Setting expiry[weekly][next][date] as : 2024-11-08 Setting expiry[weekly][next][exist] as : True
# Setting expiry[weekly][next_to_next][date] as : 2024-11-15 Setting expiry[weekly][next_to_next][exist] as : True
# Setting expiry[monthly][current][date] as : 2024-11-29 Setting expiry[monthly][current][exist] as : True
# Setting expiry[monthly][next][date] as : 2024-12-27 Setting expiry[monthly][next][exist] as : True
# Setting expiry[quarterly][current][date] as : 2025-03-28 Setting expiry[quarterly][current][exist] as : True
# Setting expiry[quarterly][next][date] as : 2025-06-27 Setting expiry[quarterly][next][exist] as : True
# Setting expiry[quarterly][next_to_next][date] as : 2025-09-26 Setting expiry[quarterly][next_to_next][exist] as : True

# %%
expiry

# %%
try :
    for i in range(1, len(quarterly_expiry_dates)+1):
        print(f"Quarterly Expiry Dates Index : {-i}, Date : {quarterly_expiry_dates[-i]}")
        if quarterly_expiry_dates[-i] in expiry_list:
            print(f"Quarterly Expiry Dates :{quarterly_expiry_dates[-i]} Exist in Expiry List")
            if expiry["quarterly"]["next_to_next_quarterly"] == None:
                expiry["quarterly"]["next_to_next_quarterly"] = quarterly_expiry_dates[-i]
                expiry["quarterly"]["next_to_next_quarterly_exist"] = True
                print(f"Setting expiry[quarterly][next_to_next_quarterly] as : {expiry["quarterly"]["next_to_next_quarterly"]}",
                      f"Setting expiry[quarterly][next_to_next_quarterly_exist] as : {expiry["quarterly"]["next_to_next_quarterly_exist"]}")
            elif expiry["quarterly"]["next_quarterly"] == None:
                expiry["quarterly"]["next_quarterly"] = quarterly_expiry_dates[-i]
                expiry["quarterly"]["next_quarterly_exist"] = True
                print(f"Setting expiry[quarterly][next_to_next_quarterly] as : {expiry["quarterly"]["next_quarterly"]}",
                      f"Setting expiry[quarterly][next_to_next_quarterly_exist] as : {expiry["quarterly"]["next_quarterly_exist"]}")
            elif expiry["quarterly"]["current_quarterly"] == None:
                expiry["quarterly"]["current_quarterly"] = quarterly_expiry_dates[-i]
                expiry["quarterly"]["current_quarterly_exist"] = True
                print(f"Setting expiry[quarterly][next_to_next_quarterly] as : {expiry["quarterly"]["current_quarterly"]}",
                      f"Setting expiry[quarterly][next_to_next_quarterly_exist] as : {expiry["quarterly"]["current_quarterly_exist"]}")

except Exception as e:
    print(f"Error Occoured while Formatting the Quarterly Expiry Dates, Error Code : {e}")

# %%
try :
    for i in range(1, len(monthly_expiry_dates)+1):
        print(f"Monthly Expiry Dates Index : {-i}, Date : {monthly_expiry_dates[-i]}")
        if monthly_expiry_dates[-i] in expiry_list:
            print(f"Monthly Expiry Dates :{monthly_expiry_dates[-i]} Exist in Expiry List")
            if expiry["monthly"]["next_to_next_monthly"] == None:
                expiry["monthly"]["next_to_next_monthly"] = monthly_expiry_dates[-i]
                expiry["monthly"]["next_to_next_monthly_exist"] = True
                print(f"Setting expiry[quarterly][next_to_next_quarterly] as : {expiry["monthly"]["next_to_next_monthly"]}",
                      f"Setting expiry[quarterly][next_to_next_quarterly_exist] as : {expiry["monthly"]["next_to_next_monthly_exist"]}")
            elif expiry["monthly"]["next_monthly"] == None:
                expiry["monthly"]["next_monthly"] = monthly_expiry_dates[-i]
                expiry["monthly"]["next_monthly_exist"] = True
                print(f"Setting expiry[quarterly][next_to_next_quarterly] as : {expiry["monthly"]["next_monthly"]}",
                      f"Setting expiry[quarterly][next_to_next_quarterly_exist] as : {expiry["monthly"]["next_monthly_exist"]}")
            elif expiry["monthly"]["current_monthly"] == None:
                expiry["monthly"]["current_monthly"] = monthly_expiry_dates[-i]
                expiry["monthly"]["current_monthly_exist"] = True
                print(f"Setting expiry[quarterly][next_to_next_quarterly] as : {expiry["monthly"]["current_monthly"]}",
                      f"Setting expiry[quarterly][next_to_next_quarterly_exist] as : {expiry["monthly"]["current_monthly_exist"]}")

except Exception as e:
    print(f"Error Occoured while Formatting the Monthly Expiry Dates, Error Code : {e}")

# %%
try :
    for i in range(1, len(weekly_expiry_dates)+1):
        print(f"Weekly Expiry Dates Index : {-i}, Date : {weekly_expiry_dates[-i]}")
        if weekly_expiry_dates[-i] in expiry_list:
            print(f"Weekly Expiry Dates :{weekly_expiry_dates[-i]} Exist in Expiry List")
            if expiry["weekly"]["next_to_next_weekly"] == None:
                expiry["weekly"]["next_to_next_weekly"] = weekly_expiry_dates[-i]
                expiry["weekly"]["next_to_next_weekly_exist"] = True
                print(f"Setting expiry[weekly][next_to_next_weekly] as : {expiry["weekly"]["next_to_next_weekly"]}",
                      f"Setting expiry[weekly][next_to_next_weekly_exist] as : {expiry["weekly"]["next_to_next_weekly_exist"]}")
            elif expiry["weekly"]["next_weekly"] == None:
                expiry["weekly"]["next_weekly"] = weekly_expiry_dates[-i]
                expiry["weekly"]["next_weekly_exist"] = True
                print(f"Setting expiry[weekly][next_to_next_weekly] as : {expiry["weekly"]["next_weekly"]}",
                      f"Setting expiry[weekly][next_to_next_weekly_exist] as : {expiry["weekly"]["next_weekly_exist"]}")
            elif expiry["weekly"]["current_weekly"] == None:
                expiry["weekly"]["current_weekly"] = weekly_expiry_dates[-i]
                expiry["weekly"]["current_weekly_exist"] = True
                print(f"Setting expiry[weekly][next_to_next_weekly] as : {expiry["weekly"]["current_weekly"]}",
                      f"Setting expiry[weekly][next_to_next_weekly_exist] as : {expiry["weekly"]["current_weekly_exist"]}")

except Exception as e:
    print(f"Error Occoured while Formatting the Weekly Expiry Dates, Error Code : {e}")

# %%
from datetime import datetime, timedelta
import pytz
import pandas as pd
import time

# %%
expiry

# %%
current_utc_datetime = datetime.now(tz=pytz.utc)

if current_utc_datetime.time().hour >= 8:
    today = current_utc_datetime.date() + timedelta(days=1)
    tomorrow = current_utc_datetime.date() + timedelta(days=2)
    day_after_tomorrow = current_utc_datetime.date() + timedelta(days=3)

elif current_utc_datetime.time().hour <= 8:
    today = current_utc_datetime.date()
    tomorrow = current_utc_datetime.date() + timedelta(days=1)
    day_after_tomorrow = current_utc_datetime.date() + timedelta(days=2)

# %%
today, tomorrow, day_after_tomorrow, current_utc_datetime

# %%
today in expiry_list, tomorrow in expiry_list, day_after_tomorrow in expiry_list

# %%
if today in expiry_list:
    expiry["daily"]["current_daily"] = today
    expiry["daily"]["current_daily_exist"] = True
else : 
    print(f"Error : {today} is not in Expiry List")

if tomorrow in expiry_list:
    expiry["daily"]["next_daily"] = tomorrow
    expiry["daily"]["next_daily_exist"] = True
else : 
    print(f"Error : {tomorrow} is not in Expiry List")

if day_after_tomorrow in expiry_list:
    expiry["daily"]["next_to_next_daily"] = day_after_tomorrow
    expiry["daily"]["next_to_next_daily_exist"] =  True
else : 
    print(f"Error : {day_after_tomorrow} is not in Expiry List")

# %%
expiry

# %%
print(f"Computing the Quarterly Expiry DataFrame ")

# Try if we can extract the Current_Quarterly Options Chain from the Primary DataFrame
# Filtering the DataFrame using Date from Quarterly_Expiry Dictionary
try:
    current_quarterly = dataframe[dataframe["expiry"] == str(expiry["quarterly"]["current_quarterly"])].copy()
    print(f"Quarterly Expiry DataFrame Length : {len(current_quarterly)}, for Date :"
          f" {str(expiry["quarterly"]["current_quarterly"])}")

# Catch the Exception Error & Print out the same for Logging Purposes
except Exception as e:
    print(f"Error in Processing Currently Quarterly Expiry {str(expiry["quarterly"]["current_quarterly"])}"
          f" : Error Details : {e}")

# Try if we can extract the Current_Quarterly Options Chain from the Primary DataFrame
# Filtering the DataFrame using Date from Quarterly_Expiry Dictionary
try:
    next_quarterly = dataframe[dataframe["expiry"] == str(expiry["quarterly"]["next_quarterly"])].copy()
    print(f"Next Quarterly Expiry DataFrame Length : {len(next_quarterly)}, for Date :"
          f" {str(expiry["quarterly"]["next_quarterly"])}")
# Catch the Exception Error & Print out the same for Logging Purposes
except Exception as e:
    print(f"Error in Processing Next Quarterly Expiry {str(expiry["quarterly"]["next_quarterly"])} : "
          f"Error Details : {e}")

# Try if we can extract the Current_Quarterly Options Chain from the Primary DataFrame
# Filtering the DataFrame using Date from Quarterly_Expiry Dictionary
try:
    next_to_next_quarterly = dataframe[dataframe["expiry"] == str(expiry["quarterly"]["next_to_next_quarterly"])].copy()

    print(f"Next to Next Quarterly Expiry DataFrame Length : {len(next_to_next_quarterly)}, for Date :"
          f" {str(expiry["quarterly"]["next_to_next_quarterly"])}")

# Catch the Exception Error & Print out the same for Logging Purposes
except Exception as e:
    print(f"Error in Processing the Next to Next Quarterly Expiry "
          f"{str(expiry["quarterly"]["next_to_next_quarterly"])} : Error Details : {e}")

# %%
next_to_next_quarterly

# %%
from src.ByBit.ByBitExpiry import ByBitExpiry

# %%
expiry_seg = ByBitExpiry()

# %%
expiry = await expiry_seg.create_options_expiry(expiry_dataframe=expiry_dates)

# %%
expiry

# %%
from src.ByBit.ByBitOptionData import ByBitOptionData

# %%
api_url = "https://api-demo.bybit.com"
api_endpoint = "/v5/market/tickers"

api_parameters = {'category': "option",
                  'baseCoin': "BTC"}

# %%
ByBitOptionData = ByBitOptionData(api_url=api_url, api_endpoint=api_endpoint, api_parameters=api_parameters)

# %%
await ByBitOptionData.fetch_ByBit_ticker_data()

# %%
await ByBitOptionData.format_the_dataframe()

# %%
(current_daily, next_daily, next_to_next_daily,
current_weekly, next_weekly, next_to_next_weekly,
current_monthly, next_monthly, next_to_next_monthly,
current_quarterly, next_quarterly, next_to_next_quarterly, expiry) = await ByBitOptionData.segregate_options_expiry()

# %%
expiry

# %%
round(0.247123 , 3)

# %%
68000 * 0.24
